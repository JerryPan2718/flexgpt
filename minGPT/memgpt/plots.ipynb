# %%
import os
# files = os.listdir(os.path.join((os.curdir, "/logs")))
csv_files = os.listdir("./logs")
csv_files.sort()
csv_files
# Out:
# ['2021-12-24-mem_selfattn_117M_K=4_test_nograd_AMP.csv',
#  '2021-12-24-mem_selfattn_1542M_K=4_test_nograd_AMP.csv',
#  '2021-12-24-mem_selfattn_345M_K=4_test_nograd_AMP.csv',
#  '2021-12-24-mem_selfattn_762M_K=4_test_nograd_AMP.csv',
#  '2021-12-28-mem_selfattn_117M_K=4_test_nograd_AMP.csv',
#  '2021-12-28-mem_selfattn_117M_K=4_test_nograd_AMP_Tc=1.csv',
#  '2021-12-28-mem_selfattn_117M_K=4_test_nograd_AMP_smallTc.csv',
#  '2021-12-28-mem_selfattn_1542M_K=4_test_nograd_AMP.csv',
#  '2021-12-28-mem_selfattn_1542M_K=4_test_nograd_AMP_Tc=1.csv',
#  '2021-12-28-mem_selfattn_1542M_K=4_test_nograd_AMP_smallTc.csv',
#  '2021-12-28-mem_selfattn_345M_K=4_test_nograd_AMP.csv',
#  '2021-12-28-mem_selfattn_345M_K=4_test_nograd_AMP_Tc=1.csv',
#  '2021-12-28-mem_selfattn_345M_K=4_test_nograd_AMP_smallTc.csv',
#  '2021-12-28-mem_selfattn_762M_K=4_test_nograd_AMP.csv',
#  '2021-12-28-mem_selfattn_762M_K=4_test_nograd_AMP_Tc=1.csv',
#  '2021-12-28-mem_selfattn_762M_K=4_test_nograd_AMP_smallTc.csv',
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df_345M = pd.read_csv("logs/mem_selfattn_345M.csv")
df_762M = pd.read_csv("logs/mem_selfattn_762M.csv")
df_small = pd.read_csv("logs/mem_selfattn_small.csv")
df_117M_test = pd.read_csv("logs/mem_selfattn_117M_K=4_test.csv")
df_345M_test = pd.read_csv("logs/mem_selfattn_345M_K=4_test.csv")
df_762M_test = pd.read_csv("logs/mem_selfattn_762M_K=4_test.csv")

# %%
x = df_345M.iloc[2, :].tolist()[1:]
y = df_345M.iloc[0, :].tolist()[1:]

plt.scatter(x[0:5], y[0:5], s=10, label="Tc=512 Tg=512")
plt.plot(x[0:5], y[0:5])
plt.scatter(x[5:10], y[5:10], s=10, label="Tc=256 Tg=256")
plt.plot(x[5:10], y[5:10])
plt.scatter(x[10:15], y[10:15], s=10, label="Tc=128 Tg=128")
plt.plot(x[10:15], y[10:15])
plt.legend(loc="lower right");
plt.xlabel("mem_mean (MB)");
plt.ylabel("runtime_mean (ms)");
plt.title("345M mem_selfattn tradeoff between runtime and memory usage");

# %%
x = df_345M.iloc[2, :].tolist()[1:]
y = df_345M.iloc[0, :].tolist()[1:]

plt.scatter(x[0:5], y[0] / y[0:5], s=10, label="Tc=512 Tg=512")
plt.plot(x[0:5], y[0] / y[0:5])
plt.scatter(x[5:10], y[5] / y[5:10], s=10, label="Tc=256 Tg=256")
plt.plot(x[5:10], y[5] / y[5:10])
plt.scatter(x[10:15], y[10] / y[10:15], s=10, label="Tc=128 Tg=128")
plt.plot(x[10:15], y[10] / y[10:15] )
plt.legend(loc="lower right");
plt.xlabel("mem_mean (MB)");
plt.ylabel("speedup_mean");
plt.title("345M mem_selfattn tradeoff between runtime and memory usage");

# %%
x = df_762M.iloc[2, :].tolist()[1:]
y = df_762M.iloc[0, :].tolist()[1:]

plt.scatter(x[0:5], y[0:5], s=10, label="Tc=512 Tg=512")
plt.plot(x[0:5], y[0:5])
plt.scatter(x[5:10], y[5:10], s=10, label="Tc=256 Tg=256")
plt.plot(x[5:10], y[5:10])
plt.scatter(x[10:15], y[10:15], s=10, label="Tc=128 Tg=128")
plt.plot(x[10:15], y[10:15])
plt.legend(loc="lower right");
plt.xlabel("mem_mean (MB)");
plt.ylabel("runtime_mean (ms)");
plt.title("762M mem_selfattn tradeoff between runtime and memory usage");

# %%
x = df_762M.iloc[2, :].tolist()[1:]
y = df_762M.iloc[0, :].tolist()[1:]

plt.scatter(x[0:5], y[0] / y[0:5], s=10, label="Tc=512 Tg=512")
plt.plot(x[0:5], y[0] / y[0:5])
plt.scatter(x[5:10], y[5] / y[5:10], s=10, label="Tc=256 Tg=256")
plt.plot(x[5:10], y[5] / y[5:10])
plt.scatter(x[10:15], y[10] / y[10:15], s=10, label="Tc=128 Tg=128")
plt.plot(x[10:15], y[10] / y[10:15] )
plt.legend(loc="lower right");
plt.xlabel("mem_mean (MB)");
plt.ylabel("speedup_mean");
plt.title("762M mem_selfattn tradeoff between runtime and memory usage");

# %%
x = df_small.iloc[2, :].tolist()[1:]
y = df_small.iloc[0, :].tolist()[1:]

plt.scatter(x[0:5], y[0:5], s=10, label="Tc=512 Tg=512")
plt.plot(x[0:5], y[0:5])
plt.scatter(x[5:10], y[5:10], s=10, label="Tc=256 Tg=256")
plt.plot(x[5:10], y[5:10])
plt.scatter(x[10:15], y[10:15], s=10, label="Tc=128 Tg=128")
plt.plot(x[10:15], y[10:15])
plt.legend(loc="lower right");
plt.xlabel("mem_mean (MB)");
plt.ylabel("runtime_mean (ms)");
plt.title("tiny mem_selfattn tradeoff between runtime and memory usage");

# %%
x = df_small.iloc[2, :].tolist()[1:]
y = df_small.iloc[0, :].tolist()[1:]

plt.scatter(x[0:5], y[0] / y[0:5], s=10, label="Tc=512 Tg=512")
plt.plot(x[0:5], y[0] / y[0:5])
plt.scatter(x[5:10], y[5] / y[5:10], s=10, label="Tc=256 Tg=256")
plt.plot(x[5:10], y[5] / y[5:10])
plt.scatter(x[10:15], y[10] / y[10:15], s=10, label="Tc=128 Tg=128")
plt.plot(x[10:15], y[10] / y[10:15] )
plt.legend(loc="lower right");
plt.xlabel("mem_mean (MB)");
plt.ylabel("speedup_mean");
plt.title("tiny mem_selfattn tradeoff between runtime and memory usage");

# %% [markdown]
# # 20211222: 117M, 345M, 762M with each module timing

# %%
x = df_117M_test.iloc[2, :].tolist()[1:]
y = df_117M_test.iloc[0, :].tolist()[1:]

plt.scatter(x[0:5], y[0:5], s=10, label="Tc=512 Tg=512")
plt.plot(x[0:5], y[0:5])
plt.scatter(x[5:10], y[5:10], s=10, label="Tc=256 Tg=256")
plt.plot(x[5:10], y[5:10])
plt.scatter(x[10:15], y[10:15], s=10, label="Tc=128 Tg=128")
plt.plot(x[10:15], y[10:15])
plt.legend(loc="lower right");
plt.xlabel("mem_mean (MB)");
plt.ylabel("runtime_mean (ms)");
plt.title("117M_test mem_selfattn tradeoff between runtime and memory usage");

# %%
x = df_117M_test.iloc[2, :].tolist()[1:]
y = df_117M_test.iloc[0, :].tolist()[1:]

plt.scatter(x[0:5], y[0] / y[0:5], s=10, label="Tc=512 Tg=512")
plt.plot(x[0:5], y[0] / y[0:5])
plt.scatter(x[5:10], y[5] / y[5:10], s=10, label="Tc=256 Tg=256")
plt.plot(x[5:10], y[5] / y[5:10])
plt.scatter(x[10:15], y[10] / y[10:15], s=10, label="Tc=128 Tg=128")
plt.plot(x[10:15], y[10] / y[10:15] )
plt.legend(loc="lower right");
plt.xlabel("mem_mean (MB)");
plt.ylabel("speedup_mean");
plt.title("117M_test mem_selfattn tradeoff between runtime and memory usage");

# %%
x = df_117M_test.iloc[2, :].tolist()[1:]
t1 = df_117M_test.iloc[4, :].tolist()[1:]
t2 = df_117M_test.iloc[5, :].tolist()[1:]
t3 = df_117M_test.iloc[6, :].tolist()[1:]

plt.scatter(x[0:5], t1[0:5], s=10, label="Tc=512 Tg=512 t1")
plt.plot(x[0:5], t1[0:5])
plt.scatter(x[0:5], t2[0:5], s=10, label="Tc=512 Tg=512 t2")
plt.plot(x[0:5], t2[0:5])
plt.scatter(x[0:5], t3[0:5], s=10, label="Tc=512 Tg=512 t3")
plt.plot(x[0:5], t3[0:5])

plt.scatter(x[5:10], t1[5:10], s=10, label="Tc=256 Tg=256 t1")
plt.plot(x[5:10], t1[5:10])
plt.scatter(x[5:10], t2[5:10], s=10, label="Tc=256 Tg=256 t2")
plt.plot(x[5:10], t2[5:10])
plt.scatter(x[5:10], t3[5:10], s=10, label="Tc=256 Tg=256 t3")
plt.plot(x[5:10], t3[5:10])

plt.scatter(x[10:15], t1[10:15], s=10, label="Tc=128 Tg=128 t1")
plt.plot(x[10:15], t1[10:15])
plt.scatter(x[10:15], t2[10:15], s=10, label="Tc=128 Tg=128 t2")
plt.plot(x[10:15], t2[10:15])
plt.scatter(x[10:15], t3[10:15], s=10, label="Tc=128 Tg=128 t3")
plt.plot(x[10:15], t3[10:15])

plt.legend(loc="lower right");
plt.xlabel("mem_mean (MB)");
plt.ylabel("t1_mean (ms)");
plt.title("117M_test mem_selfattn tradeoff between runtime t1 t2 t3 and memory usage");

# %%
x = df_117M_test.iloc[2, :].tolist()[1:]
t1 = df_117M_test.iloc[4, :].tolist()[1:]
t2 = df_117M_test.iloc[5, :].tolist()[1:]
t3 = df_117M_test.iloc[6, :].tolist()[1:]

plt.scatter(x[0:5], t1[0] / t1[0:5], s=10, label="Tc=512 Tg=512 t1")
plt.plot(x[0:5], t1[0] / t1[0:5])
plt.scatter(x[0:5], t2[0] / t2[0:5], s=10, label="Tc=512 Tg=512 t2")
plt.plot(x[0:5], t2[0] / t2[0:5])
plt.scatter(x[0:5], t3[0] / t3[0:5], s=10, label="Tc=512 Tg=512 t3")
plt.plot(x[0:5], t3[0] / t3[0:5])

plt.scatter(x[5:10], t1[5] / t1[5:10], s=10, label="Tc=256 Tg=256 t1")
plt.plot(x[5:10], t1[5] / t1[5:10])
plt.scatter(x[5:10], t2[5] / t2[5:10], s=10, label="Tc=256 Tg=256 t2")
plt.plot(x[5:10], t2[5] / t2[5:10])
plt.scatter(x[5:10], t3[5] / t3[5:10], s=10, label="Tc=256 Tg=256 t3")
plt.plot(x[5:10], t3[5] / t3[5:10])

plt.scatter(x[10:15], t1[10] / t1[10:15], s=10, label="Tc=128 Tg=128 t1")
plt.plot(x[10:15], t1[10] / t1[10:15])
plt.scatter(x[10:15], t2[10] / t2[10:15], s=10, label="Tc=128 Tg=128 t2")
plt.plot(x[10:15], t2[10] / t2[10:15])
plt.scatter(x[10:15], t3[10] / t3[10:15], s=10, label="Tc=128 Tg=128 t3")
plt.plot(x[10:15], t3[10] / t3[10:15])

plt.legend(loc="lower right");
plt.xlabel("mem_mean (MB)");
plt.ylabel("speedup_mean");
plt.title("117M_test mem_selfattn tradeoff between runtime and memory usage");

# %%
df_117M_test
# Out:
#          Unnamed: 0  Tc=512 Tg=512 cache_length=0  \
# 0  runtime_mean(ms)                   3452.452057
# 1   runtime_std(ms)                      2.944628
# 2      mem_mean(MB)                    437.235926
# 3       mem_std(MB)                     76.352927
# 4        t1_mean(s)                   1325.189003
# 5         t1_std(s)                      0.784733
# 6        t2_mean(s)                    705.114892
# 7         t2_std(s)                      0.132763
# 8        t3_mean(s)                   1113.185788
# 9         t3_std(s)                      0.440397
#
#    Tc=512 Tg=512 cache_length=128.0  Tc=512 Tg=512 cache_length=256.0  \
# 0                       3169.135590                       2790.005127
# 1                          1.552033                          1.371626
# 2                        789.397846                       1141.585502
# 3                         76.341003                         76.336813
# ...

# %%
x = df_345M_test.iloc[2, :].tolist()[1:]
y = df_345M_test.iloc[0, :].tolist()[1:]

plt.scatter(x[0:5], y[0:5], s=10, label="Tc=512 Tg=512")
plt.plot(x[0:5], y[0:5])
plt.scatter(x[5:10], y[5:10], s=10, label="Tc=256 Tg=256")
plt.plot(x[5:10], y[5:10])
plt.scatter(x[10:15], y[10:15], s=10, label="Tc=128 Tg=128")
plt.plot(x[10:15], y[10:15])
plt.legend(loc="lower right");
plt.xlabel("mem_mean (MB)");
plt.ylabel("runtime_mean (ms)");
plt.title("345M_test mem_selfattn tradeoff between runtime and memory usage");

# %%
x = df_345M_test.iloc[2, :].tolist()[1:]
y = df_345M_test.iloc[0, :].tolist()[1:]

plt.scatter(x[0:5], y[0] / y[0:5], s=10, label="Tc=512 Tg=512")
plt.plot(x[0:5], y[0] / y[0:5])
plt.scatter(x[5:10], y[5] / y[5:10], s=10, label="Tc=256 Tg=256")
plt.plot(x[5:10], y[5] / y[5:10])
plt.scatter(x[10:15], y[10] / y[10:15], s=10, label="Tc=128 Tg=128")
plt.plot(x[10:15], y[10] / y[10:15] )
plt.legend(loc="lower right");
plt.xlabel("mem_mean (MB)");
plt.ylabel("speedup_mean");
plt.title("345M_test mem_selfattn tradeoff between runtime and memory usage");

# %%
x = df_762M_test.iloc[2, :].tolist()[1:]
y = df_762M_test.iloc[0, :].tolist()[1:]

plt.scatter(x[0:5], y[0:5], s=10, label="Tc=512 Tg=512")
plt.plot(x[0:5], y[0:5])
plt.scatter(x[5:10], y[5:10], s=10, label="Tc=256 Tg=256")
plt.plot(x[5:10], y[5:10])
plt.scatter(x[10:15], y[10:15], s=10, label="Tc=128 Tg=128")
plt.plot(x[10:15], y[10:15])
plt.legend(loc="lower right");
plt.xlabel("mem_mean (MB)");
plt.ylabel("runtime_mean (ms)");
plt.title("762M_test mem_selfattn tradeoff between runtime and memory usage");

# %%
x = df_762M_test.iloc[2, :].tolist()[1:]
y = df_762M_test.iloc[0, :].tolist()[1:]

plt.scatter(x[0:5], y[0] / y[0:5], s=10, label="Tc=512 Tg=512")
plt.plot(x[0:5], y[0] / y[0:5])
plt.scatter(x[5:10], y[5] / y[5:10], s=10, label="Tc=256 Tg=256")
plt.plot(x[5:10], y[5] / y[5:10])
plt.scatter(x[10:15], y[10] / y[10:15], s=10, label="Tc=128 Tg=128")
plt.plot(x[10:15], y[10] / y[10:15] )
plt.legend(loc="lower right");
plt.xlabel("mem_mean (MB)");
plt.ylabel("speedup_mean");
plt.title("762M_test mem_selfattn tradeoff between runtime and memory usage");

# %%
x = df_762M_test.iloc[2, :].tolist()[1:]
t1 = df_762M_test.iloc[4, :].tolist()[1:]
t2 = df_762M_test.iloc[5, :].tolist()[1:]
t3 = df_762M_test.iloc[6, :].tolist()[1:]

plt.scatter(x[0:5], t1[0:5], s=10, label="Tc=512 Tg=512 t1")
plt.plot(x[0:5], t1[0:5])
plt.scatter(x[0:5], t2[0:5], s=10, label="Tc=512 Tg=512 t2")
plt.plot(x[0:5], t2[0:5])
plt.scatter(x[0:5], t3[0:5], s=10, label="Tc=512 Tg=512 t3")
plt.plot(x[0:5], t3[0:5])

plt.scatter(x[5:10], t1[5:10], s=10, label="Tc=256 Tg=256 t1")
plt.plot(x[5:10], t1[5:10])
plt.scatter(x[5:10], t2[5:10], s=10, label="Tc=256 Tg=256 t2")
plt.plot(x[5:10], t2[5:10])
plt.scatter(x[5:10], t3[5:10], s=10, label="Tc=256 Tg=256 t3")
plt.plot(x[5:10], t3[5:10])

plt.scatter(x[10:15], t1[10:15], s=10, label="Tc=128 Tg=128 t1")
plt.plot(x[10:15], t1[10:15])
plt.scatter(x[10:15], t2[10:15], s=10, label="Tc=128 Tg=128 t2")
plt.plot(x[10:15], t2[10:15])
plt.scatter(x[10:15], t3[10:15], s=10, label="Tc=128 Tg=128 t3")
plt.plot(x[10:15], t3[10:15])

plt.legend(loc="lower right");
plt.xlabel("mem_mean (MB)");
plt.ylabel("t1_mean (ms)");
plt.title("762M_test mem_selfattn tradeoff between runtime t1 t2 t3 and memory usage");

# %%
x = df_762M_test.iloc[2, :].tolist()[1:]
t1 = df_762M_test.iloc[4, :].tolist()[1:]
t2 = df_762M_test.iloc[5, :].tolist()[1:]
t3 = df_762M_test.iloc[6, :].tolist()[1:]

plt.scatter(x[0:5], t1[0] / t1[0:5], s=10, label="Tc=512 Tg=512 t1", color="red")
plt.plot(x[0:5], t1[0] / t1[0:5], color="red", marker="o", markersize=3, linewidth=1)
plt.scatter(x[0:5], t2[0] / t2[0:5], s=10, label="Tc=512 Tg=512 t2", color="blue")
plt.plot(x[0:5], t2[0] / t2[0:5], color="blue", marker="s", markersize=4, linewidth=1)
plt.scatter(x[0:5], t3[0] / t3[0:5], s=10, label="Tc=512 Tg=512 t3", color="green")
plt.plot(x[0:5], t3[0] / t3[0:5], color="green", marker="*", markersize=8, linewidth=1)

plt.scatter(x[5:10], t1[5] / t1[5:10], s=10, label="Tc=256 Tg=256 t1", color="red")
plt.plot(x[5:10], t1[5] / t1[5:10], color="red", marker="o", markersize=3, linewidth=1)
plt.scatter(x[5:10], t2[5] / t2[5:10], s=10, label="Tc=256 Tg=256 t2", color="blue")
plt.plot(x[5:10], t2[5] / t2[5:10], color="blue", marker="s", markersize=4, linewidth=1)
plt.scatter(x[5:10], t3[5] / t3[5:10], s=10, label="Tc=256 Tg=256 t3", color="green")
plt.plot(x[5:10], t3[5] / t3[5:10], color="green", marker="*", markersize=8, linewidth=1)

plt.scatter(x[10:15], t1[10] / t1[10:15], s=10, label="Tc=128 Tg=128 t1", color="red")
plt.plot(x[10:15], t1[10] / t1[10:15], color="red", marker="o", markersize=3, linewidth=1)
plt.scatter(x[10:15], t2[10] / t2[10:15], s=10, label="Tc=128 Tg=128 t2", color="blue")
plt.plot(x[10:15], t2[10] / t2[10:15], color="blue", marker="s", markersize=4, linewidth=1)
plt.scatter(x[10:15], t3[10] / t3[10:15], s=10, label="Tc=128 Tg=128 t3", color="green")
plt.plot(x[10:15], t3[10] / t3[10:15], color="green", marker="*", markersize=8, linewidth=1)

plt.legend(loc="lower right");
plt.xlabel("mem_mean (MB)");
plt.ylabel("speedup_mean");
plt.title("762M_test mem_selfattn tradeoff between runtime and memory usage");

# %% [markdown]
# # 20211223: no_grad, AMP

# %%
plot_idx = 0
for csv_file in csv_files:
    if csv_file[-33:] != "M_K=4_test_zeropad_nograd_AMP.csv":
        continue
    df = pd.read_csv("logs/" + csv_file)
    print(csv_file)
    x = df.iloc[2, :].tolist()[1:]
    t = df.iloc[0, :].tolist()[1:]
    t1 = df.iloc[4, :].tolist()[1:]
    t2 = df.iloc[5, :].tolist()[1:]
    t3 = df.iloc[6, :].tolist()[1:]
    
    plt.figure(plot_idx)
    plot_idx += 1
    plt.scatter(x[0:5], t[0:5], s=10, label="Tc=512 Tg=512 t")
    plt.plot(x[0:5], t[0:5])
    plt.scatter(x[0:5], t[0:5], s=10, label="Tc=512 Tg=512 t")
    plt.plot(x[0:5], t[0:5])
    plt.scatter(x[0:5], t2[0:5], s=10, label="Tc=512 Tg=512 t2")
    plt.plot(x[0:5], t2[0:5])
    plt.scatter(x[0:5], t3[0:5], s=10, label="Tc=512 Tg=512 t3")
    plt.plot(x[0:5], t3[0:5])
    
    plt.scatter(x[5:10], t[5:10], s=10, label="Tc=256 Tg=256 t")
    plt.plot(x[5:10], t[5:10])
    plt.scatter(x[5:10], t1[5:10], s=10, label="Tc=256 Tg=256 t1")
    plt.plot(x[5:10], t1[5:10])
    plt.scatter(x[5:10], t2[5:10], s=10, label="Tc=256 Tg=256 t2")
    plt.plot(x[5:10], t2[5:10])
    plt.scatter(x[5:10], t3[5:10], s=10, label="Tc=256 Tg=256 t3")
    plt.plot(x[5:10], t3[5:10])
    
    plt.scatter(x[10:15], t[10:15], s=10, label="Tc=128 Tg=128 t")
    plt.plot(x[10:15], t[10:15])
    plt.scatter(x[10:15], t1[10:15], s=10, label="Tc=128 Tg=128 t1")
    plt.plot(x[10:15], t1[10:15])
    plt.scatter(x[10:15], t2[10:15], s=10, label="Tc=128 Tg=128 t2")
    plt.plot(x[10:15], t2[10:15])
    plt.scatter(x[10:15], t3[10:15], s=10, label="Tc=128 Tg=128 t3")
    plt.plot(x[10:15], t3[10:15])

    plt.legend(loc="lower right")
    plt.xlabel("mem_mean (MB)")
    plt.ylabel("t1_mean (ms)")
    plt.title(f"{csv_files[13:16]}M_test mem_selfattn tradeoff between runtime t1 t2 t3 and memory usage");

    ####################################################################################
    plt.figure(plot_idx)
    plot_idx += 1
    plt.scatter(x[0:5], t[0] / t[0:5], s=10, label="Tc=512 Tg=512 t", color="black")
    plt.plot(x[0:5], t[0] / t[0:5], color="black", linewidth=1)
    plt.scatter(x[0:5], t1[0] / t1[0:5], s=10, label="Tc=512 Tg=512 t1", color="red")
    plt.plot(x[0:5], t1[0] / t1[0:5], color="red", marker="o", markersize=3, linewidth=1)
    plt.scatter(x[0:5], t2[0] / t2[0:5], s=10, label="Tc=512 Tg=512 t2", color="blue")
    plt.plot(x[0:5], t2[0] / t2[0:5], color="blue", marker="s", markersize=4, linewidth=1)
    plt.scatter(x[0:5], t3[0] / t3[0:5], s=10, label="Tc=512 Tg=512 t3", color="green")
    plt.plot(x[0:5], t3[0] / t3[0:5], color="green", marker="*", markersize=8, linewidth=1)

    plt.scatter(x[5:10], t1[5] / t1[5:10], s=10, label="Tc=256 Tg=256 t1", color="red")
    plt.plot(x[5:10], t1[5] / t1[5:10], color="red", marker="o", markersize=3, linewidth=1)
    plt.scatter(x[5:10], t2[5] / t2[5:10], s=10, label="Tc=256 Tg=256 t2", color="blue")
    plt.plot(x[5:10], t2[5] / t2[5:10], color="blue", marker="s", markersize=4, linewidth=1)
    plt.scatter(x[5:10], t3[5] / t3[5:10], s=10, label="Tc=256 Tg=256 t3", color="green")
    plt.plot(x[5:10], t3[5] / t3[5:10], color="green", marker="*", markersize=8, linewidth=1)

    plt.scatter(x[10:15], t1[10] / t1[10:15], s=10, label="Tc=128 Tg=128 t1", color="red")
    plt.plot(x[10:15], t1[10] / t1[10:15], color="red", marker="o", markersize=3, linewidth=1)
    plt.scatter(x[10:15], t2[10] / t2[10:15], s=10, label="Tc=128 Tg=128 t2", color="blue")
    plt.plot(x[10:15], t2[10] / t2[10:15], color="blue", marker="s", markersize=4, linewidth=1)
    plt.scatter(x[10:15], t3[10] / t3[10:15], s=10, label="Tc=128 Tg=128 t3", color="green")
    plt.plot(x[10:15], t3[10] / t3[10:15], color="green", marker="*", markersize=8, linewidth=1)

    plt.legend(loc="lower right")
    plt.xlabel("mem_mean (MB)")
    plt.ylabel("speedup_mean")
    print(csv_file[13:16])
    plt.title(f"{csv_file[13:16]}M_test mem_selfattn tradeoff between runtime and memory usage");
# Out:
# mem_selfattn_345M_K=4_test_zeropad_nograd_AMP.csv
# 345
# mem_selfattn_117M_K=4_test_zeropad_nograd_AMP.csv
# 117
# mem_selfattn_1542M_K=4_test_zeropad_nograd_AMP.csv
# 154
# mem_selfattn_762M_K=4_test_zeropad_nograd_AMP.csv
# 762

# %%
plot_idx = 0
for csv_file in csv_files:
    if csv_file[-23:] != "K=4_test_nograd_AMP.csv":
        continue
    df = pd.read_csv("logs/" + csv_file)
    hparam = csv_file.split("_")[2]
    print(hparam)
    x = df.iloc[2, :].tolist()[1:]
    t = df.iloc[0, :].tolist()[1:]
    t1 = df.iloc[4, :].tolist()[1:]
    t2 = df.iloc[5, :].tolist()[1:]
    t3 = df.iloc[6, :].tolist()[1:]
    
    plt.figure(plot_idx)
    plot_idx += 1
    plt.scatter(x[0:5], t[0:5], s=10, label="Tc=512 Tg=512")
    plt.plot(x[0:5], t[0:5])
    plt.scatter(x[5:10], t[5:10], s=10, label="Tc=256 Tg=256")
    plt.plot(x[5:10], t[5:10])
    plt.scatter(x[10:15], t[10:15], s=10, label="Tc=128 Tg=128")
    plt.plot(x[10:15], t[10:15])

    plt.legend(loc="lower right")
    plt.xlabel("mem_mean (MB)")
    plt.ylabel("t_mean (ms)")
    plt.title(f"{hparam}_test mem_selfattn tradeoff between runtime t1 t2 t3 and memory usage");

    ####################################################################################
    plt.figure(plot_idx)
    plot_idx += 1
    plt.scatter(x[0:5], t[0] / t[0:5], s=10, label="Tc=512 Tg=512")
    plt.plot(x[0:5], t[0] / t[0:5])
    plt.scatter(x[5:10], t[5] / t[5:10], s=10, label="Tc=256 Tg=256")
    plt.plot(x[5:10], t[5] / t[5:10])
    plt.scatter(x[10:15], t[10] / t[10:15], s=10, label="Tc=128 Tg=128")
    plt.plot(x[10:15], t[10] / t[10:15] )

    plt.legend(loc="lower right")
    plt.xlabel("mem_mean (MB)")
    plt.ylabel("speedup_mean")
    plt.title(f"{hparam}_test mem_selfattn tradeoff between runtime and memory usage");
# Out:
# 117M
# 762M
# 345M
# 1542M
# 345M
# 1542M
# 762M
# 117M

# %% [markdown]
# # 20211227: with FLOPs

# %%
plot_idx = 0
for csv_file in csv_files:
    if csv_file[:10] != "2021-12-28":
        continue
    df = pd.read_csv("logs/" + csv_file)
    hparam = csv_file.split("_")[2]
    print(hparam)
    x = df.iloc[2, :].tolist()[1:]
    t = df.iloc[0, :].tolist()[1:]
    t1 = df.iloc[4, :].tolist()[1:]
    t2 = df.iloc[5, :].tolist()[1:]
    t3 = df.iloc[6, :].tolist()[1:]
    flops = df.iloc[10, :].tolist()[1:]
    plt.figure(plot_idx)
    plot_idx += 1
    plt.scatter(x[0:5], t[0:5], s=10, label="Tc=512 Tg=512")
    plt.plot(x[0:5], t[0:5])
#     plt.plot(x[0:5], np.log(flops[0:5]))
    plt.scatter(x[5:10], t[5:10], s=10, label="Tc=256 Tg=256")
    plt.plot(x[5:10], t[5:10])
#     plt.plot(x[0:5], np.log(flops[5:10]))
    plt.scatter(x[10:15], t[10:15], s=10, label="Tc=128 Tg=128")
    plt.plot(x[10:15], t[10:15])
#     plt.plot(x[0:5], np.log(flops[10:15]))

    plt.legend(loc="lower right")
    plt.xlabel("mem_mean (MB)")
    plt.ylabel("t_mean (ms)")
    plt.title(f"{hparam}_test mem_selfattn tradeoff between runtime t1 t2 t3 and memory usage");

    ####################################################################################
    plt.figure(plot_idx)
    plot_idx += 1
    plt.scatter(x[0:5], t[0] / t[0:5], s=10, label="Tc=512 Tg=512 speedups")
    plt.plot(x[0:5], t[0] / t[0:5])
    plt.scatter(x[5:10], t[5] / t[5:10], s=10, label="Tc=256 Tg=256 speedups")
    plt.plot(x[5:10], t[5] / t[5:10])
    plt.scatter(x[10:15], t[10] / t[10:15], s=10, label="Tc=128 Tg=128 speedups")
    plt.plot(x[10:15], t[10] / t[10:15])
    
    plt.plot(x[0:5], np.log(flops[0] / flops[0:5]), label="Tc=512 Tg=512 log flops")
    plt.plot(x[5:10], np.log(flops[5] / flops[5:10]), label="Tc=256 Tg=256 log flops")
    plt.plot(x[10:15], np.log(flops[10] / flops[10:15]), label="Tc=128 Tg=128 log flops")

    plt.legend(loc="lower right")
    plt.xlabel("mem_mean (MB)")
    plt.ylabel("speedup_mean")
    plt.title(f"{hparam}_test mem_selfattn tradeoff between runtime and memory usage");
# Out:
# 117M
# 762M
# 345M
# 1542M

# %%
plot_idx = 0
for csv_file in csv_files:
    if csv_file[:10] != "2021-12-28" and csv_file[-12:] != "_smallTc.csv":
        continue
    df = pd.read_csv("logs/" + csv_file)
    hparam = csv_file.split("_")[2]
    print(hparam)
    x = df.iloc[2, :].tolist()[1:]
    t = df.iloc[0, :].tolist()[1:]
    t1 = df.iloc[4, :].tolist()[1:]
    t2 = df.iloc[5, :].tolist()[1:]
    t3 = df.iloc[6, :].tolist()[1:]
    flops = df.iloc[10, :].tolist()[1:]
    plt.figure(plot_idx)
    plot_idx += 1
    plt.scatter(x[0:5], t[0:5], s=10, label="Tc=512 Tg=64")
    plt.plot(x[0:5], t[0:5])
#     plt.plot(x[0:5], np.log(flops[0:5]))
    plt.scatter(x[5:10], t[5:10], s=10, label="Tc=256 Tg=64")
    plt.plot(x[5:10], t[5:10])
#     plt.plot(x[0:5], np.log(flops[5:10]))
    plt.scatter(x[10:15], t[10:15], s=10, label="Tc=128 Tg=64")
    plt.plot(x[10:15], t[10:15])
#     plt.plot(x[0:5], np.log(flops[10:15]))

    plt.legend(loc="lower right")
    plt.xlabel("mem_mean (MB)")
    plt.ylabel("t_mean (ms)")
    plt.title(f"{hparam}_test mem_selfattn tradeoff between runtime t1 t2 t3 and memory usage");

    ####################################################################################
    plt.figure(plot_idx)
    plot_idx += 1
    plt.scatter(x[0:5], t[0] / t[0:5], s=10, label="Tc=512 Tg=64 speedups")
    plt.plot(x[0:5], t[0] / t[0:5])
    plt.scatter(x[5:10], t[5] / t[5:10], s=10, label="Tc=256 Tg=64 speedups")
    plt.plot(x[5:10], t[5] / t[5:10])
    plt.scatter(x[10:15], t[10] / t[10:15], s=10, label="Tc=128 Tg=64 speedups")
    plt.plot(x[10:15], t[10] / t[10:15])
    
#     plt.plot(x[0:5], np.log(flops[0] / flops[0:5]), label="Tc=512 Tg=512 log flops")
#     plt.plot(x[5:10], np.log(flops[5] / flops[5:10]), label="Tc=256 Tg=256 log flops")
#     plt.plot(x[10:15], np.log(flops[10] / flops[10:15]), label="Tc=128 Tg=128 log flops")

    plt.legend(loc="lower right")
    plt.xlabel("mem_mean (MB)")
    plt.ylabel("speedup_mean")
    plt.title(f"{hparam}_test mem_selfattn tradeoff between runtime and memory usage");
# Out:
# 117M
# 762M
# 345M
# 345M
# 1542M
# 1542M
# 762M
# 117M

# %% [markdown]
# # 20211228: Tc=1

# %%
plot_idx = 0
for csv_file in csv_files:
    if csv_file[:10] != "2021-12-28" or csv_file[-8:] != "Tc=1.csv":
        continue
    df = pd.read_csv("logs/" + csv_file)
    hparam = csv_file.split("_")[2]
    print(hparam)
    x = df.iloc[2, :].tolist()[1:]
    t = df.iloc[0, :].tolist()[1:]
    t1 = df.iloc[4, :].tolist()[1:]
    t2 = df.iloc[5, :].tolist()[1:]
    t3 = df.iloc[6, :].tolist()[1:]
    flops = df.iloc[10, :].tolist()[1:]
    plt.figure(plot_idx)
    plot_idx += 1
    plt.scatter(x[0:5], t[0:5], s=10, label="Tc=512 Tg=64")
    plt.plot(x[0:5], t[0:5])
#     plt.plot(x[0:5], np.log(flops[0:5]))
    plt.scatter(x[5:10], t[5:10], s=10, label="Tc=256 Tg=64")
    plt.plot(x[5:10], t[5:10])
#     plt.plot(x[0:5], np.log(flops[5:10]))
    plt.scatter(x[10:15], t[10:15], s=10, label="Tc=128 Tg=64")
    plt.plot(x[10:15], t[10:15])
#     plt.plot(x[0:5], np.log(flops[10:15]))

    plt.legend(loc="lower right")
    plt.xlabel("mem_mean (MB)")
    plt.ylabel("t_mean (ms)")
    plt.title(f"{hparam}_test mem_selfattn tradeoff between runtime t1 t2 t3 and memory usage");

    ####################################################################################
    plt.figure(plot_idx)
    plot_idx += 1
    plt.scatter(x[0:5], t[0] / t[0:5], s=10, label="Tc=512 Tg=64 speedups")
    plt.plot(x[0:5], t[0] / t[0:5])
    plt.scatter(x[5:10], t[5] / t[5:10], s=10, label="Tc=256 Tg=64 speedups")
    plt.plot(x[5:10], t[5] / t[5:10])
    plt.scatter(x[10:15], t[10] / t[10:15], s=10, label="Tc=128 Tg=64 speedups")
    plt.plot(x[10:15], t[10] / t[10:15])
    
#     plt.plot(x[0:5], np.log(flops[0] / flops[0:5]), label="Tc=512 Tg=512 log flops")
#     plt.plot(x[5:10], np.log(flops[5] / flops[5:10]), label="Tc=256 Tg=256 log flops")
#     plt.plot(x[10:15], np.log(flops[10] / flops[10:15]), label="Tc=128 Tg=128 log flops")

    plt.legend(loc="lower right")
    plt.xlabel("mem_mean (MB)")
    plt.ylabel("speedup_mean")
    plt.title(f"{hparam}_test mem_selfattn tradeoff between runtime and memory usage");
# Out:
# 117M
# 1542M
# 345M
# 762M

# %% [markdown]
# # 20220105: mem_demo

# %%
df = pd.read_csv("logs/2022-01-05-mem_demo-1542M_K=4.csv")
df
# Out:
#          Unnamed: 0  model_size=117M Tg=256 cache_length=0  \
# 0  runtime_mean(ms)                             4355.96582
# 1   runtime_std(ms)                                0.00000
#
#    model_size=117M Tg=256 cache_length=64.0  \
# 0                               4352.073242
# 1                                  0.000000
#
#    model_size=117M Tg=256 cache_length=128.0  \
# 0                                4293.923828
# 1                                   0.000000
#
#    model_size=117M Tg=256 cache_length=256  \
# 0                               4411.30127
# 1                                  0.00000
#
#    model_size=117M Tg=512 cache_length=0  \
# 0                            8717.605469
# 1                               0.000000
#
#    model_size=117M Tg=512 cache_length=128.0  \
# 0                                8802.364258
# 1                                   0.000000
#
#    model_size=117M Tg=512 cache_length=256.0  \
# 0                                8660.258789
# ...

# %% [markdown]
# # 20220116 freddie: mem_selfattn baseline (cuda=11.6 pytorch=1.10.0)

# %%
df = pd.read_csv("logs/2022-01-16-mem_selfattn_1542M_K=4_test_nograd_AMP_todevice_optimized_t1t2t3_T=32.csv")
print(df)
x = df.iloc[2, :].tolist()[1:]
t = df.iloc[0, :].tolist()[1:]
t1 = df.iloc[4, :].tolist()[1:]
t2 = df.iloc[5, :].tolist()[1:]
t3 = df.iloc[6, :].tolist()[1:]
flops = df.iloc[10, :].tolist()[1:]
plt.figure(plot_idx)
plot_idx += 1
plt.scatter(x[0:5], t[0:5], s=10, label="Tc=32 Tg=128")
plt.plot(x[0:5], t[0:5])
#     plt.plot(x[0:5], np.log(flops[0:5]))
# plt.scatter(x[5:10], t[5:10], s=10, label="Tc=32 Tg=128")
# plt.plot(x[5:10], t[5:10])
# #     plt.plot(x[0:5], np.log(flops[5:10]))
# plt.scatter(x[10:15], t[10:15], s=10, label="Tc=32 Tg=128")
# plt.plot(x[10:15], t[10:15])
#     plt.plot(x[0:5], np.log(flops[10:15]))

plt.legend(loc="lower right")
plt.xlabel("mem_mean (MB)")
plt.ylabel("t_mean (ms)")
plt.title(f"{hparam}_test mem_selfattn tradeoff between runtime t1 t2 t3 and memory usage");

####################################################################################
plt.figure(plot_idx)
plot_idx += 1
plt.scatter(x[0:5], t[0] / t[0:5], s=10, label="Tc=32 Tg=128 speedups")
plt.plot(x[0:5], t[0] / t[0:5])
# plt.scatter(x[5:10], t[5] / t[5:10], s=10, label="Tc=256 Tg=64 speedups")
# plt.plot(x[5:10], t[5] / t[5:10])
# plt.scatter(x[10:15], t[10] / t[10:15], s=10, label="Tc=128 Tg=64 speedups")
# plt.plot(x[10:15], t[10] / t[10:15])

#     plt.plot(x[0:5], np.log(flops[0] / flops[0:5]), label="Tc=512 Tg=512 log flops")
#     plt.plot(x[5:10], np.log(flops[5] / flops[5:10]), label="Tc=256 Tg=256 log flops")
#     plt.plot(x[10:15], np.log(flops[10] / flops[10:15]), label="Tc=128 Tg=128 log flops")

plt.legend(loc="lower right")
plt.xlabel("mem_mean (MB)")
plt.ylabel("speedup_mean")
plt.title(f"{hparam}_test mem_selfattn tradeoff between runtime and memory usage");
# Out:
#           Unnamed: 0  Tc=32 Tg=128 cache_length=0  \
# 0   runtime_mean(ms)                 1.553966e+03
# 1    runtime_std(ms)                 6.853675e+00
# 2       mem_mean(MB)                 4.259430e+02
# 3        mem_std(MB)                 4.260879e+01
# 4         t1_mean(s)                 1.208955e+03
# 5          t1_std(s)                 3.754850e+00
# 6         t2_mean(s)                 1.360136e+02
# 7          t2_std(s)                 1.023588e+01
# 8         t3_mean(s)                 8.637313e+01
# 9          t3_std(s)                 3.114309e-01
# 10             flops                 3.133501e+10
#
#     Tc=32 Tg=128 cache_length=32.0  Tc=32 Tg=128 cache_length=64.0  \
# 0                     1.432125e+03                    1.187101e+03
# 1                     2.886913e+01                    2.352552e+01
# 2                     5.498324e+02                    6.741542e+02
# 3                     4.224672e+01                    4.202668e+01
# ...

# %%
df = pd.read_csv("logs/2022-01-16-mem_selfattn_1542M_K=4_test_nograd_AMP_todevice_optimized_t1t2t3_T=32_Ts*4.csv")
# print(df)
hparam = "1542M"
x = df.iloc[2, :].tolist()[1:]
t = df.iloc[0, :].tolist()[1:]
t1 = df.iloc[4, :].tolist()[1:]
t2 = df.iloc[5, :].tolist()[1:]
t3 = df.iloc[6, :].tolist()[1:]
flops = df.iloc[10, :].tolist()[1:]

plt.figure(plot_idx)
plot_idx += 1
plt.scatter(x[0:5], t[0:5], s=10, label="Tc=32 Tg=512")
plt.plot(x[0:5], t[0:5])
plt.scatter(x[5:10], t[5:10], s=10, label="Tc=32 Tg=256")
plt.plot(x[5:10], t[5:10])
plt.scatter(x[10:15], t[10:15], s=10, label="Tc=32 Tg=128")
plt.plot(x[10:15], t[10:15])

plt.legend(loc="lower right")
plt.xlabel("mem_mean (MB)")
plt.ylabel("t_mean (ms)")
plt.title(f"{hparam}_test mem_selfattn tradeoff between runtime t1 t2 t3 and memory usage");

####################################################################################
plt.figure(plot_idx)
plot_idx += 1
plt.scatter(x[0:5], t[0] / t[0:5], s=10, label="Tc=32 Tg=128 speedups")
plt.plot(x[0:5], t[0] / t[0:5])
plt.scatter(x[5:10], t[5] / t[5:10], s=10, label="Tc=32 Tg=256 speedups")
plt.plot(x[5:10], t[5] / t[5:10])
plt.scatter(x[10:15], t[10] / t[10:15], s=10, label="Tc=32 Tg=512 speedups")
plt.plot(x[10:15], t[10] / t[10:15])

# plt.plot(x[0:5], np.log(flops[0] / flops[0:5]), label="Tc=512 Tg=512 log flops")
# plt.plot(x[5:10], np.log(flops[5] / flops[5:10]), label="Tc=256 Tg=256 log flops")
# plt.plot(x[10:15], np.log(flops[10] / flops[10:15]), label="Tc=128 Tg=128 log flops")

plt.legend(loc="lower right")
plt.xlabel("mem_mean (MB)")
plt.ylabel("speedup_mean")
plt.title(f"{hparam}_test mem_selfattn tradeoff between runtime and memory usage");
